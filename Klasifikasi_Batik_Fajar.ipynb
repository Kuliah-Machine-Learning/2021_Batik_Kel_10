# %% [markdown]
# <a href="https://colab.research.google.com/github/Kuliah-Machine-Learning/2021_Batik_Kel_10/blob/main/Klasifikasi_Batik_Fajar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Kuliah-Machine-Learning/2021_Batik_Kel_10.git
# Out:
# Cloning into '2021_Batik_Kel_10'...
# remote: Enumerating objects: 109, done.
# remote: Counting objects: 100% (109/109), done.
# remote: Compressing objects: 100% (108/108), done.
# remote: Total 109 (delta 0), reused 109 (delta 0), pack-reused 0
# Receiving objects: 100% (109/109), 2.43 MiB | 26.79 MiB/s, done.

# %%
# %cd 2021_Batik_Kel_10
# Out:
# /content/2021_Batik_Kel_10

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

try:
  # The %tensorflow_version magic only works in colab.
  # %tensorflow_version 2.x
except Exception:
  pass
import numpy as np 
import math, os, sys
import itertools

import matplotlib.pyplot as plt
plt.style.use('default')
from scipy import ndimage

from skimage import measure, morphology
from skimage.io import imsave, imread
from skimage.filters import threshold_otsu
from skimage.transform import resize

import tensorflow as tf
from sklearn import svm, datasets
from sklearn.metrics import confusion_matrix
import pandas as pd

# %%
#Perintah di bawah ini untuk melihat list bagian dari file yang sudah diunduh dari Github
# !ls Dataset/
# !ls Dataset/train/pekalongan
# !ls Dataset/train/cirebon
# Out:
# test  train
# pekalongan_10.jpg  pekalongan_1.jpg   pekalongan_29.jpg  pekalongan_38.jpg
# pekalongan_11.jpg  pekalongan_20.jpg  pekalongan_2.jpg	 pekalongan_39.jpg
# pekalongan_12.jpg  pekalongan_21.jpg  pekalongan_30.jpg  pekalongan_3.jpg
# pekalongan_13.jpg  pekalongan_22.jpg  pekalongan_31.jpg  pekalongan_40.jpg
# pekalongan_14.jpg  pekalongan_23.jpg  pekalongan_32.jpg  pekalongan_4.jpg
# pekalongan_15.jpg  pekalongan_24.jpg  pekalongan_33.jpg  pekalongan_5.jpg
# pekalongan_16.jpg  pekalongan_25.jpg  pekalongan_34.jpg  pekalongan_6.jpg
# pekalongan_17.jpg  pekalongan_26.jpg  pekalongan_35.jpg  pekalongan_7.jpg
# pekalongan_18.jpg  pekalongan_27.jpg  pekalongan_36.jpg  pekalongan_8.jpg
# pekalongan_19.jpg  pekalongan_28.jpg  pekalongan_37.jpg  pekalongan_9.jpg
# cirebon_10.jpg	cirebon_18.jpg	cirebon_25.jpg	cirebon_32.jpg	cirebon_3.jpg
# cirebon_11.jpg	cirebon_19.jpg	cirebon_26.jpg	cirebon_33.jpg	cirebon_40.jpg
# cirebon_12.jpg	cirebon_1.jpg	cirebon_27.jpg	cirebon_34.jpg	cirebon_4.jpg
# cirebon_13.jpg	cirebon_20.jpg	cirebon_28.jpg	cirebon_35.jpg	cirebon_5.jpg
# cirebon_14.jpg	cirebon_21.jpg	cirebon_29.jpg	cirebon_36.jpg	cirebon_6.jpg
# cirebon_15.jpg	cirebon_22.jpg	cirebon_2.jpg	cirebon_37.jpg	cirebon_7.jpg
# cirebon_16.jpg	cirebon_23.jpg	cirebon_30.jpg	cirebon_38.jpg	cirebon_8.jpg
# cirebon_17.jpg	cirebon_24.jpg	cirebon_31.jpg	cirebon_39.jpg	cirebon_9.jpg

# %%
#Perintah untuk memvisualisasikan satu gambar dari data train
image = imread("Dataset/train/pekalongan/pekalongan_11.jpg")
plt.figure(figsize=(3,3))
plt.imshow(image)

# %%
#Memuat semua gambar ke memori untuk pertama kali

#Memuat dataset pelatihan
IMAGE_SIZE = 200
BATCH_SIZE = 45
base_dir = os.path.join('Dataset/train')

datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255, 
    validation_split=0.1)

train_generator = datagen.flow_from_directory(
    base_dir,
    target_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE, 
    subset='training')

val_generator = datagen.flow_from_directory(
    base_dir,
    target_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE, 
    subset='validation')

#Memuat dataset pengujian
X_test = []
y_test = []
labels = ['pekalongan', 'cirebon']

for i,label in enumerate(labels):
    folder = os.path.join("Dataset/test",label)
    files = sorted(os.listdir(folder))
    files = [x for x in files if x.endswith(".jpg")]
    for k,file in enumerate(files):
        image_path = os.path.join(folder, file)
        
        image = imread(image_path)/255.
        image = resize(image,(200,200))
        X_test.append(image)
        category = os.path.split(folder)[-1]
        y_test.append(i)

X_test = np.array(X_test)
y_test = np.array(y_test)

#Menampilkan bentuk dari masing-masing dataset
for image_batch, label_batch in train_generator:
  break
print("Bentuk array dari dataset train (pelatihan) adalah:", image_batch.shape,label_batch.shape)
for image_batch, label_batch in val_generator:
  break
print("Bentuk array dari dataset validation (validasi) adalah:", image_batch.shape,label_batch.shape)
print("Bentuk array dari dataset test (pengujian) adalah:", X_test.shape,y_test.shape)
# Out:
# Found 72 images belonging to 2 classes.
# Found 8 images belonging to 2 classes.
# Bentuk array dari dataset train (pelatihan) adalah: (45, 200, 200, 3) (45, 2)
# Bentuk array dari dataset validation (validasi) adalah: (8, 200, 200, 3) (8, 2)
# Bentuk array dari dataset test (pengujian) adalah: (20, 200, 200, 3) (20,)

# %%
print (train_generator.class_indices)

labels_txt = '\n'.join(sorted(train_generator.class_indices.keys()))

with open('labels.txt', 'w') as f:
  f.write(labels_txt)
# Out:
# {'cirebon': 0, 'pekalongan': 1}

# %%
# !cat labels.txt
# Out:
# cirebon
# pekalongan

# %%
IMG_SHAPE = (200, 200, 3)
#Membuat dasar(base model) dari pre-trained model VGG16:
base_model = tf.keras.applications.VGG16(input_shape=IMG_SHAPE,
                                              include_top=False,
                                              weights='imagenet')

# %%
base_model.trainable = False
base_model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 0
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
import keras
from keras import backend as K
from keras.models import Sequential
from keras import layers
from keras.utils.np_utils import to_categorical

from sklearn.model_selection import train_test_split

# %%
y_test2 = to_categorical(y_test)
X_test3, y_test3 = (X_test, y_test2)

# %%
model = tf.keras.Sequential([
   base_model,
   tf.keras.layers.Conv2D(32, 4, activation='relu'),
   tf.keras.layers.GlobalAveragePooling2D(),
   tf.keras.layers.Dense(2, activation='softmax')                          
])

model.compile("adam",loss="categorical_crossentropy",metrics=["acc"])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 6, 6, 512)         14714688
#
#  conv2d_1 (Conv2D)           (None, 3, 3, 32)          262176
#
#  global_average_pooling2d_1   (None, 32)               0
#  (GlobalAveragePooling2D)
#
#  dense_1 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 14,976,930
# Trainable params: 14,976,930
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit_generator(train_generator,
                              epochs=50,
                              validation_data=val_generator)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   This is separate from the ipykernel package so we can avoid doing imports until
# Epoch 1/50
# 2/2 [==============================] - 110s 69s/step - loss: 19.4729 - acc: 0.5417 - val_loss: 0.8787 - val_acc: 0.5000
# Epoch 2/50
# 2/2 [==============================] - 110s 70s/step - loss: 0.7472 - acc: 0.5417 - val_loss: 1.0080 - val_acc: 0.5000
# Epoch 3/50
# 2/2 [==============================] - 108s 43s/step - loss: 0.9039 - acc: 0.5694 - val_loss: 6.1983 - val_acc: 0.5000
# Epoch 4/50
# 2/2 [==============================] - 107s 68s/step - loss: 2.0962 - acc: 0.5000 - val_loss: 0.8214 - val_acc: 0.5000
# Epoch 5/50
# 2/2 [==============================] - 108s 68s/step - loss: 0.7728 - acc: 0.4444 - val_loss: 0.6985 - val_acc: 0.5000
# Epoch 6/50
# 2/2 [==============================] - 109s 69s/step - loss: 0.7057 - acc: 0.4167 - val_loss: 0.6896 - val_acc: 0.6250
# Epoch 7/50
# 2/2 [==============================] - 109s 43s/step - loss: 0.7254 - acc: 0.5278 - val_loss: 0.6933 - val_acc: 0.5000
# Epoch 8/50
# 2/2 [==============================] - 109s 69s/step - loss: 0.7020 - acc: 0.5000 - val_loss: 0.6956 - val_acc: 0.5000
# Epoch 9/50
# 2/2 [==============================] - 110s 44s/step - loss: 0.6954 - acc: 0.5000 - val_loss: 0.6949 - val_acc: 0.3750
# Epoch 10/50
# 2/2 [==============================] - 109s 69s/step - loss: 0.6908 - acc: 0.5833 - val_loss: 0.6993 - val_acc: 0.5000
# Epoch 11/50
# 2/2 [==============================] - 109s 43s/step - loss: 0.6902 - acc: 0.5000 - val_loss: 0.7081 - val_acc: 0.5000
# Epoch 12/50
# 2/2 [==============================] - 109s 43s/step - loss: 0.6927 - acc: 0.5417 - val_loss: 0.7036 - val_acc: 0.5000
# Epoch 13/50
# 2/2 [==============================] - 110s 70s/step - loss: 0.6964 - acc: 0.5417 - val_loss: 0.6972 - val_acc: 0.3750
# Epoch 14/50
# 2/2 [==============================] - 110s 43s/step - loss: 0.6986 - acc: 0.5417 - val_loss: 0.6992 - val_acc: 0.5000
# Epoch 15/50
# 2/2 [==============================] - 109s 69s/step - loss: 0.6917 - acc: 0.5000 - val_loss: 0.6960 - val_acc: 0.3750
# Epoch 16/50
# 2/2 [==============================] - 108s 69s/step - loss: 0.6829 - acc: 0.6528 - val_loss: 0.6993 - val_acc: 0.3750
# Epoch 17/50
# 2/2 [==============================] - 108s 68s/step - loss: 0.6860 - acc: 0.5833 - val_loss: 0.7012 - val_acc: 0.5000
# Epoch 18/50
# 2/2 [==============================] - 108s 42s/step - loss: 0.6947 - acc: 0.5139 - val_loss: 0.6977 - val_acc: 0.5000
# Epoch 19/50
# 2/2 [==============================] - 109s 43s/step - loss: 0.6712 - acc: 0.6389 - val_loss: 0.7013 - val_acc: 0.5000
# Epoch 20/50
# 2/2 [==============================] - 108s 69s/step - loss: 0.6602 - acc: 0.5972 - val_loss: 0.7151 - val_acc: 0.3750
# Epoch 21/50
# 2/2 [==============================] - 111s 69s/step - loss: 0.7225 - acc: 0.4444 - val_loss: 0.6990 - val_acc: 0.6250
# Epoch 22/50
# 2/2 [==============================] - 108s 69s/step - loss: 0.6314 - acc: 0.6806 - val_loss: 0.7499 - val_acc: 0.5000
# Epoch 23/50
# 2/2 [==============================] - 108s 43s/step - loss: 0.6523 - acc: 0.6111 - val_loss: 0.7327 - val_acc: 0.5000
# Epoch 24/50
# 2/2 [==============================] - 109s 43s/step - loss: 0.7697 - acc: 0.5000 - val_loss: 0.6705 - val_acc: 0.6250
# Epoch 25/50
# 2/2 [==============================] - 108s 43s/step - loss: 0.6538 - acc: 0.5972 - val_loss: 0.8116 - val_acc: 0.5000
# Epoch 26/50
# 2/2 [==============================] - 108s 43s/step - loss: 0.7045 - acc: 0.5000 - val_loss: 0.7548 - val_acc: 0.5000
# Epoch 27/50
# 2/2 [==============================] - 108s 42s/step - loss: 0.6856 - acc: 0.6944 - val_loss: 0.6949 - val_acc: 0.3750
# Epoch 28/50
# 2/2 [==============================] - 109s 69s/step - loss: 0.6138 - acc: 0.7083 - val_loss: 0.6549 - val_acc: 0.6250
# Epoch 29/50
# 2/2 [==============================] - 109s 70s/step - loss: 0.5756 - acc: 0.7639 - val_loss: 0.6360 - val_acc: 0.7500
# Epoch 30/50
# 2/2 [==============================] - 108s 68s/step - loss: 0.4905 - acc: 0.8194 - val_loss: 0.7803 - val_acc: 0.8750
# Epoch 31/50
# 2/2 [==============================] - 108s 69s/step - loss: 0.5519 - acc: 0.7361 - val_loss: 0.9361 - val_acc: 0.6250
# Epoch 32/50
# 2/2 [==============================] - 110s 43s/step - loss: 0.5112 - acc: 0.7639 - val_loss: 0.7064 - val_acc: 0.5000
# Epoch 33/50
# 2/2 [==============================] - 110s 70s/step - loss: 0.6508 - acc: 0.6389 - val_loss: 0.8001 - val_acc: 0.5000
# Epoch 34/50
# 2/2 [==============================] - 108s 43s/step - loss: 0.6467 - acc: 0.5417 - val_loss: 0.6993 - val_acc: 0.2500
# Epoch 35/50
# 2/2 [==============================] - 107s 42s/step - loss: 0.5825 - acc: 0.8056 - val_loss: 0.6152 - val_acc: 0.5000
# Epoch 36/50
# 2/2 [==============================] - 109s 43s/step - loss: 0.4605 - acc: 0.8611 - val_loss: 0.5470 - val_acc: 0.7500
# Epoch 37/50
# 2/2 [==============================] - 108s 69s/step - loss: 0.4012 - acc: 0.8333 - val_loss: 0.5136 - val_acc: 0.7500
# Epoch 38/50
# 2/2 [==============================] - 109s 70s/step - loss: 0.2616 - acc: 0.8750 - val_loss: 0.6554 - val_acc: 0.5000
# Epoch 39/50
# 2/2 [==============================] - 109s 68s/step - loss: 0.3026 - acc: 0.8889 - val_loss: 0.5611 - val_acc: 0.8750
# Epoch 40/50
# 2/2 [==============================] - 108s 43s/step - loss: 0.3971 - acc: 0.8750 - val_loss: 0.5621 - val_acc: 0.8750
# Epoch 41/50
# 2/2 [==============================] - 108s 68s/step - loss: 0.2910 - acc: 0.8750 - val_loss: 0.5306 - val_acc: 0.8750
# Epoch 42/50
# 2/2 [==============================] - 108s 69s/step - loss: 0.1701 - acc: 0.9583 - val_loss: 0.4997 - val_acc: 0.6250
# Epoch 43/50
# 2/2 [==============================] - 108s 43s/step - loss: 0.2695 - acc: 0.8611 - val_loss: 0.3365 - val_acc: 0.8750
# Epoch 44/50
# 2/2 [==============================] - 108s 42s/step - loss: 0.1569 - acc: 0.9444 - val_loss: 0.7401 - val_acc: 0.7500
# Epoch 45/50
# 2/2 [==============================] - 108s 43s/step - loss: 0.2029 - acc: 0.9167 - val_loss: 0.2725 - val_acc: 0.8750
# Epoch 46/50
# 2/2 [==============================] - 108s 43s/step - loss: 0.1579 - acc: 0.9444 - val_loss: 0.2228 - val_acc: 0.8750
# Epoch 47/50
# 2/2 [==============================] - 108s 43s/step - loss: 0.1350 - acc: 0.9722 - val_loss: 0.7536 - val_acc: 0.8750
# Epoch 48/50
# 2/2 [==============================] - 108s 43s/step - loss: 0.0954 - acc: 0.9722 - val_loss: 1.0752 - val_acc: 0.8750
# Epoch 49/50
# 2/2 [==============================] - 108s 68s/step - loss: 0.0840 - acc: 0.9722 - val_loss: 2.2048 - val_acc: 0.8750
# Epoch 50/50
# 2/2 [==============================] - 108s 68s/step - loss: 0.1055 - acc: 0.9444 - val_loss: 0.3792 - val_acc: 0.8750

# %%
plt.plot(history.history["acc"],label="Akurasi Pelatihan")
plt.plot(history.history["val_acc"],label="Validasi_Akurasi")
plt.legend()
plt.show()

plt.plot(history.history["loss"],label="Kesalahan Pelatihan")
plt.plot(history.history["val_loss"],label="Validasi_Kesalahan")
plt.legend()
plt.show()

# %%
print('Number of trainable variables = {}'.format(len(model.trainable_variables)))
# Out:
# Number of trainable variables = 30

# %%
print(train_generator)
# Out:
# <keras.preprocessing.image.DirectoryIterator object at 0x7fbaf5b25a50>

# %%
#Prediksi Label Validasi dengan Pelatihan
n = 7
input_image = image_batch[n][np.newaxis,...]
print("Labelnya adalah: ", label_batch[n])

predictions = model.predict(input_image)
print("Prediksinya adalah",predictions[0])
# Out:
# Labelnya adalah:  [0. 1.]
# Prediksinya adalah [4.4693887e-11 1.0000000e+00]

# %%
print(model.metrics_names)
print(model.evaluate(train_generator))
print(model.evaluate(val_generator))
print(model.evaluate(x= X_test3, y = y_test3))

# %%
y_true = np.argmax(y_test2,axis=1)

y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)

print(y_true)
print(y_pred)

# %%
n = 7

plt.imshow(X_test[n])
plt.show()

true_label = np.argmax(y_test2,axis=1)[n]
print("Label yang Benar:",true_label,":",labels[true_label])
prediction = model.predict(X_test[n][np.newaxis,...])[0]
print("Nilai yang diprediksi :",prediction)
predicted_label = np.argmax(prediction)
print("Label yang diprediksi :",predicted_label,":",labels[predicted_label])

if true_label == predicted_label:
  print("Prediksi Benar")
else:
  print("Prediksi Salah")
# Out:
# Label yang Benar: 0 : pekalongan
# Nilai yang diprediksi : [0.97102994 0.02897007]
# Label yang diprediksi : 0 : pekalongan
# Prediksi Benar

# %%
from sklearn.metrics import confusion_matrix
from sklearn.utils.multiclass import unique_labels

def plot_confusion_matrix(y_true, y_pred, classes,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if not title:
        if normalize:
            title = 'Normalized confusion matrix'
        else:
            title = 'Confusion matrix, without normalization'

    # Compute confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    # Only use the labels that appear in the data
    #classes = classes[unique_labels(y_true, y_pred)]
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)
fig, ax = plt.subplots(figsize=(5,5))
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    #ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=classes, yticklabels=classes,
           title=title,
           ylabel='Label Benar',
           xlabel='Label Prediksi')

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")

    # Loop over data dimensions and create text annotations.
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    return ax


np.set_printoptions(precision=2)

plot_confusion_matrix(y_true, y_pred, classes=labels, normalize=True,
                      title='Normalized confusion matrix')

# %%
saved_model_dir = 'save/model'
tf.saved_model.save(model, saved_model_dir)

converter = tf.lite.TFLiteConverter.from_saved_model(saved_model_dir)
tflite_model = converter.convert()

with open('Klasifikasi Motif Kain Batik_Kel_2__VGG_16Net.tflite', 'wb') as f:
  f.write(tflite_model)
